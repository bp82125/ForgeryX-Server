# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt


def plot_image(image, title="Image"):
    if isinstance(image, bytes):
        image = np.frombuffer(image, np.uint8)
        image = cv2.imdecode(image, cv2.IMREAD_COLOR)

    if len(image.shape) == 3 and image.shape[2] == 3:
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    plt.figure(figsize=(8, 8))
    plt.imshow(image, cmap="gray" if len(image.shape) == 2 else None)
    plt.title(title)
    plt.axis("off")
    plt.show()

# %%
img_folder = "/home/nhat82125/ForgeryX-Server/example"
img_name = "39"

tp_img_path = os.path.join(img_folder, f"{img_name}.jpg")
# gt_img_path = os.path.join(img_folder, f"{img_name}.png")

tp_img = cv2.imread(tp_img_path)
# gt_img = cv2.imread(gt_img_path)

plot_image(tp_img, "Tampered Image")
# plot_image(gt_img, "Ground Truth Image")

# %%
import orjson

from get_metadata import get_metadata

metadata = get_metadata(tp_img_path)

for key, value in metadata.items():
    print(f"{key}: {value}")
# Out:
# SourceFile: /home/nhat82125/ForgeryX-Server/example/39.jpg
# ExifToolVersion: 12.76
# FileName: 39.jpg
# Directory: /home/nhat82125/ForgeryX-Server/example
# FileSize: Filesize 862 kB
# FileModifyDate: 2025:01:09 01:52:28+07:00
# FileAccessDate: 2025:03:14 15:11:22+07:00
# FileInodeChangeDate: 2025:03:12 23:15:26+07:00
# FilePermissions: 100644
# FileType: JPEG
# FileTypeExtension: JPG
# MIMEType: image/jpeg
# ExifByteOrder: Little-Endian (Intel byte order)
# CurrentIPTCDigest: d6b41b3dd7cfb1ea9db45d4314f4e2cc
# ImageWidth: 3264
# ImageHeight: 2448
# EncodingProcess: Extended Sequential DCT (Huffman Coding)
# BitsPerSample: 8 8 8
# ColorComponents: 3
# YCbCrSubSampling: YCbCr4:4:4 (1 1)
# PhotometricInterpretation: 2
# Make: Canon
# Model: Canon PowerShot A630
# Orientation: Horizontal (normal)
# SamplesPerPixel: 3
# XResolution: 180
# YResolution: 180
# ResolutionUnit: Inches
# Software: Adobe Photoshop CS6 (Macintosh)
# ModifyDate: 2015:10:24 17:07:57+03:00
# YCbCrPositioning: Centered
# ExposureTime: 0.002
# FNumber: 4.1
# ISO: 75
# ExifVersion: 0220
# DateTimeOriginal: 2015:08:29 11:55:24
# CreateDate: 2015:08:29 11:55:24
# ComponentsConfiguration: Y, Cb, Cr, -
# CompressedBitsPerPixel: 2
# ShutterSpeedValue: 0.00199589286846507
# ApertureValue: 4.08758859461647
# ExposureCompensation: 0
# MaxApertureValue: 4.08758859461647
# MeteringMode: Multi-segment
# Flash: Auto, Did not fire
# FocalLength: 29.2
# UserComment:
# FlashpixVersion: 0100
# ColorSpace: sRGB
# ExifImageWidth: 3264
# ExifImageHeight: 2448
# InteropIndex: R98 - DCF basic file (sRGB)
# InteropVersion: 0100
# RelatedImageWidth: 3264
# RelatedImageHeight: 2448
# FocalPlaneXResolution: 18188.81119
# FocalPlaneYResolution: 18231.30841
# FocalPlaneResolutionUnit: 2
# SensingMethod: One-chip color area
# FileSource: 3
# CustomRendered: Normal
# ExposureMode: Auto
# WhiteBalance: Auto
# DigitalZoomRatio: 1.59375
# SceneCaptureType: Standard
# Compression: 6
# ThumbnailOffset: 1230
# ThumbnailLength: 9260
# ThumbnailImage: (Binary data 9260 bytes, use -b option to extract)
# CodedCharacterSet: %G
# ApplicationRecordVersion: 0
# DateCreated: 2015:08:29 11:55:24
# TimeCreated: 11:55:24+00:00
# IPTCDigest: d6b41b3dd7cfb1ea9db45d4314f4e2cc
# DisplayedUnitsX: 1
# DisplayedUnitsY: 1
# PrintStyle: 0
# PrintPosition: 0 0
# PrintScale: 1
# GlobalAngle: 30
# GlobalAltitude: 30
# URL_List: []
# SlicesGroupName: gull_fake
# NumSlices: 1
# PixelAspectRatio: 1
# PhotoshopThumbnail: (Binary data 9260 bytes, use -b option to extract)
# HasRealMergedData: 1
# WriterName: Adobe Photoshop
# ReaderName: Adobe Photoshop CS6
# PhotoshopQuality: 4
# PhotoshopFormat: 257
# ProgressiveScans: 1
# XMPToolkit: Adobe XMP Core 5.3-c011 66.145661, 2012/02/06-14:56:27
# LensInfo: 7.3 29.2 undef undef
# Lens: 7.3-29.2 mm
# ApproximateFocusDistance: 9.51
# FlashCompensation: 0
# Firmware: 1.0
# MetadataDate: 2015:10:24 17:07:57+03:00
# ColorMode: 3
# ICCProfileName: sRGB IEC61966-2.1
# DocumentID: 35C9A7D520D1C92712BC7D91C9CABFB9
# InstanceID: xmp.iid:06801174072068118083C432BE61490B
# OriginalDocumentID: 35C9A7D520D1C92712BC7D91C9CABFB9
# Format: image/jpeg
# HistoryAction: saved
# HistoryInstanceID: xmp.iid:06801174072068118083C432BE61490B
# HistoryWhen: 2015:10:24 17:07:57+03:00
# HistorySoftwareAgent: Adobe Photoshop CS6 (Macintosh)
# HistoryChanged: /
# ProfileCMMType: Lino
# ProfileVersion: Unknown profile version
# ProfileClass: Display Device Profile
# ColorSpaceData: RGB
# ProfileConnectionSpace: XYZ
# ProfileDateTime: 1998:02:09 06:49:00
# ProfileFileSignature: acsp
# PrimaryPlatform: MSFT
# CMMFlags: Not Embedded, Independent
# DeviceManufacturer: Hewlett-Packard
# DeviceModel: sRGB
# DeviceAttributes: Reflective, Glossy, Positive Polarity
# RenderingIntent: Perceptual
# ConnectionSpaceIlluminant: 0.9642 1 0.82491
# ProfileCreator: Unknown device manufacturer
# ProfileID: 00000000000000000000000000000000
# ProfileCopyright: Copyright (c) 1998 Hewlett-Packard Company
# ProfileDescription: sRGB IEC61966-2.1
# MediaWhitePoint: 0.95045 1 1.08905
# MediaBlackPoint: 0 0 0
# RedMatrixColumn: 0.43607 0.22249 0.01392
# GreenMatrixColumn: 0.38515 0.71687 0.09708
# BlueMatrixColumn: 0.14307 0.06061 0.7141
# DeviceMfgDesc: IEC http://www.iec.ch
# DeviceModelDesc: IEC 61966-2.1 Default RGB colour space - sRGB
# ViewingCondDesc: Reference Viewing Condition in IEC61966-2.1
# ViewingCondIlluminant: 19.6445 20.3718 16.8089
# ViewingCondSurround: 3.92889 4.07439 3.36179
# ViewingCondIlluminantType: 1
# Luminance: 76.03647 80 87.12462
# MeasurementObserver: 1
# MeasurementBacking: 0 0 0
# MeasurementGeometry: 0
# MeasurementFlare: 0.00999
# MeasurementIlluminant: 2
# Technology: CRT
# RedTRC: (Binary data 2060 bytes, use -b option to extract)
# GreenTRC: (Binary data 2060 bytes, use -b option to extract)
# BlueTRC: (Binary data 2060 bytes, use -b option to extract)
# DCTEncodeVersion: 100
# APP14Flags0: 0
# APP14Flags1: 0
# ColorTransform: 1
# Aperture: 4.1
# ImageSize: 3264x2448
# Megapixels: 8.0
# ScaleFactor35efl: 7.6
# ShutterSpeed: 1/500 sec
# DateTimeCreated: 2015:08:29 11:55:24+00:00
# CircleOfConfusion: 0.004 mm
# DOF: 8.0577548396001 11.6008078477111
# FOV: 9.3°
# FocalLength35efl: 29.2 mm
# HyperfocalDistance: 52.6 m
# LightValue: 13.5
# LensID: 7.3-29.2 mm
